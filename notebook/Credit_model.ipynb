# %%
import sys 
import pandas as pd
sys.path.insert(0, '/10 A KAI 2/WEEK 8&9/Fraud_detection/')

# %%
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
from script.model1 import  FraudModel

# %%
Data = pd.read_csv('../Data/credit_merged.csv', index_col=0)

# %%
Data.rename(columns={'Class': 'class'}, inplace=True)

# %%
model = FraudModel(Data, dataset_name="Credit", source="Credit Data Source")

# %%
import mlflow
mlflow.start_run()
# Out:
# <ActiveRun: >

# %%
Data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'class'],
#       dtype='object')

# %%
model.model_logistic_regression()
# Out:
# 2024/10/22 19:49:47 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 19:49:47 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 19:49:47 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 19:49:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 19:50:30 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# Logging metrics for model: Logistic Regression
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/22 19:50:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# LogisticRegression()

# %%
model.model_decision_tree()
# Out:
# 2024/10/22 19:20:07 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 19:20:07 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 19:20:07 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 19:20:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 19:21:48 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: AttributeError("'str' object has no attribute 'predict'"). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2024/10/22 19:21:48 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# Logging metrics for model: Decision Tree
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/22 19:21:51 WARNING mlflow.models.model: Failed to validate serving input example {
#   "dataframe_split": {
#     "columns": [
#       "Time",
#       "V1",
#       "V2",
#       "V3",
#       "V4",
#       "V5",
#       "V6",
#       "V7",
#       "V8",
#       "V9",
#       "V10",
#       "V11",
#       "V12",
#       "V13",
#       "V14",
#       "V15",
#       "V16",
#       "V17",
#       "V18",
#       "V19",
#       "V20",
#       "V21",
#       "V22",
#       "V23",
#       "V24",
#       "V25",
#       "V26",
#       "V27",
#       "V28",
#       "Amount"
#     ],
#     "data": [
#       [
#         1.413094928943472,
#         1.94674666728168,
#         -0.752525821492348,
#         -1.35512953289131,
#         -0.661629913230695,
#         1.50282190770174,
#         4.02493282673061,
#         -1.47966148383909,
#         1.13988021689572,
#         1.40681871374813,
#         -0.157402912660682,
#         -0.113729190329599,
#         0.510277474082635,
#         0.0612577807353701,
#         -0.0665551394957695,
#         1.32870182050036,
#         0.352513902823239,
#         -0.76566982664618,
#         0.141937536859382,
#         -0.451364651514137,
#         -0.134434695487417,
#         0.0761965101986691,
#         0.297536541043559,
#         0.307914569497895,
#         0.690980284177926,
#         -0.350316231256655,
#         -0.388907264903717,
#         0.0776408382302655,
#         -0.0322477642202041,
#         -0.3239634020271977
#       ]
#     ]
#   }
# }. Alternatively, you can avoid passing input example and pass model signature instead when logging the model. To ensure the input example is valid prior to serving, please try calling `mlflow.models.validate_serving_input` on the model uri and serving input example. A serving input example can be generated from model input example using `mlflow.models.convert_input_example_to_serving_input` function.
# Got error: Model does not have the "python_function" flavor
# DecisionTreeClassifier()

# %%
model.model_random_forest()
# Out:
# 2024/10/22 19:21:51 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 19:21:51 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 19:21:51 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 19:21:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 19:32:46 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: AttributeError("'str' object has no attribute 'predict'"). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`. To disable automatic signature inference, set `signature` to `False` in your `log_model` or `save_model` call.
# 2024/10/22 19:32:46 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# Logging metrics for model: Random Forest
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/22 19:32:50 WARNING mlflow.models.model: Failed to validate serving input example {
#   "dataframe_split": {
#     "columns": [
#       "Time",
#       "V1",
#       "V2",
#       "V3",
#       "V4",
#       "V5",
#       "V6",
#       "V7",
#       "V8",
#       "V9",
#       "V10",
#       "V11",
#       "V12",
#       "V13",
#       "V14",
#       "V15",
#       "V16",
#       "V17",
#       "V18",
#       "V19",
#       "V20",
#       "V21",
#       "V22",
#       "V23",
#       "V24",
#       "V25",
#       "V26",
#       "V27",
#       "V28",
#       "Amount"
#     ],
#     "data": [
#       [
#         1.413094928943472,
#         1.94674666728168,
#         -0.752525821492348,
#         -1.35512953289131,
#         -0.661629913230695,
#         1.50282190770174,
#         4.02493282673061,
#         -1.47966148383909,
#         1.13988021689572,
#         1.40681871374813,
#         -0.157402912660682,
#         -0.113729190329599,
#         0.510277474082635,
#         0.0612577807353701,
#         -0.0665551394957695,
#         1.32870182050036,
#         0.352513902823239,
#         -0.76566982664618,
#         0.141937536859382,
#         -0.451364651514137,
#         -0.134434695487417,
#         0.0761965101986691,
#         0.297536541043559,
#         0.307914569497895,
#         0.690980284177926,
#         -0.350316231256655,
#         -0.388907264903717,
#         0.0776408382302655,
#         -0.0322477642202041,
#         -0.3239634020271977
#       ]
#     ]
#   }
# }. Alternatively, you can avoid passing input example and pass model signature instead when logging the model. To ensure the input example is valid prior to serving, please try calling `mlflow.models.validate_serving_input` on the model uri and serving input example. A serving input example can be generated from model input example using `mlflow.models.convert_input_example_to_serving_input` function.
# Got error: Model does not have the "python_function" flavor
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:607, in TrackingServiceClient.log_param(self, run_id, key, value, synchronous)
#     606 if synchronous:
# --> 607     self.store.log_param(run_id, param)
#     608     return value
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\mlflow\store\tracking\file_store.py:999, in FileStore.log_param(self, run_id, param)
#     998 check_run_is_active(run_info)
# --> 999 self._log_run_param(run_info, param)
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\mlflow\store\tracking\file_store.py:1005, in FileStore._log_run_param(self, run_info, param)
#    1004 if os.path.exists(param_path):
# -> 1005     self._validate_new_param_value(
#    1006         param_path=param_path,
#    1007         param_key=param.key,
#    1008         run_id=run_info.run_id,
#    1009         new_value=writeable_param_value,
#    1010     )
#    1011 make_containing_dirs(param_path)
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\mlflow\store\tracking\file_store.py:1025, in FileStore._validate_new_param_value(self, param_path, param_key, run_id, new_value)
#    1024 if current_value != new_value:
# -> 1025     raise MlflowException(
#    1026         f"Changing param values is not allowed. Param with key='{param_key}' was already"
#    1027         f" logged with value='{current_value}' for run ID='{run_id}'. Attempted logging"
#    1028         f" new value '{new_value}'.",
#    1029         databricks_pb2.INVALID_PARAMETER_VALUE,
#    1030     )
#
# MlflowException: Changing param values is not allowed. Param with key='n_estimators' was already logged with value='100' for run ID='8c0fbe87c4d7467dbe4147683962e32f'. Attempted logging new value '50'.
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model.model_random_forest()
#
# File d:\10 A KAI 2/WEEK 8&9/Fraud_detection\script\model1.py:128, in model_random_forest(self)
#     127 def model_gradient_boosting(self):
# --> 128     start_time = time.time()
#     129     with mlflow.start_run(run_name=f"{self.dataset_name} - Gradient Boosting", nested=True):
#     130         X_train_res, y_train_res, X_test, y_test = self.apply_smote()
#
# File d:\10 A KAI 2/WEEK 8&9/Fraud_detection\script\model1.py:83, in FraudModel.log_metrics(self, model_name, X_train_res, y_train_res, y_test, y_pred, hyperparameters, duration)
#      81 if hyperparameters:
#      82     for key, value in hyperparameters.items():
# ---> 83         mlflow.log_param(key, value)
#      85 # Log metrics
#      86 mlflow.log_metric("accuracy", accuracy)
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\mlflow\tracking\fluent.py:698, in log_param(key, value, synchronous)
#     696 run_id = _get_or_start_run().info.run_id
#     697 synchronous = synchronous if synchronous is not None else not MLFLOW_ENABLE_ASYNC_LOGGING.get()
# --> 698 return MlflowClient().log_param(run_id, key, value, synchronous=synchronous)
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\mlflow\tracking\client.py:1598, in MlflowClient.log_param(self, run_id, key, value, synchronous)
#    1594 synchronous = (
#    1595     synchronous if synchronous is not None else not MLFLOW_ENABLE_ASYNC_LOGGING.get()
#    1596 )
#    1597 if synchronous:
# -> 1598     self._tracking_client.log_param(run_id, key, value, synchronous=True)
#    1599     return value
#    1600 else:
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:614, in TrackingServiceClient.log_param(self, run_id, key, value, synchronous)
#     612 if e.error_code == ErrorCode.Name(INVALID_PARAMETER_VALUE):
#     613     msg = f"{e.message}{PARAM_VALIDATION_MSG}"
# --> 614     raise MlflowException(msg, INVALID_PARAMETER_VALUE)
#     615 else:
#     616     raise e
#
# MlflowException: Changing param values is not allowed. Param with key='n_estimators' was already logged with value='100' for run ID='8c0fbe87c4d7467dbe4147683962e32f'. Attempted logging new value '50'.
#
# The cause of this error is typically due to repeated calls
# to an individual run_id event logging.
#
# Incorrect Example:
# ---------------------------------------
# with mlflow.start_run():
#     mlflow.log_param("depth", 3)
#     mlflow.log_param("depth", 5)
# ---------------------------------------
#
# Which will throw an MlflowException for overwriting a
# logged parameter.
#
# Correct Example:
# ---------------------------------------
# with mlflow.start_run():
#     with mlflow.start_run(nested=True):
#         mlflow.log_param("depth", 3)
#     with mlflow.start_run(nested=True):
#         mlflow.log_param("depth", 5)
# ---------------------------------------
#
# Which will create a new nested run for each individual
# model and prevent parameter key collisions within the
# tracking store.

# %%
model.model_gradient_boosting()
# Out:
# 2024/10/21 22:52:03 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/21 22:52:03 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/21 22:52:03 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/21 22:52:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 00:13:45 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# Logging metrics for model: Gradient Boosting
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/22 00:13:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Logging hyperparameter - n_estimators: 100
# Logging hyperparameter - learning_rate: 0.1
# GradientBoostingClassifier()

# %%
# Other model calls...
model.model_mlp()
# Out:
# 2024/10/22 20:15:20 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 20:15:20 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 20:15:20 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 20:15:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 1/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 29s 2ms/step - accuracy: 0.9869 - loss: 0.0384
# Epoch 2/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 26s 2ms/step - accuracy: 0.9989 - loss: 0.0050
# Epoch 3/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 26s 2ms/step - accuracy: 0.9992 - loss: 0.0036
# Epoch 4/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - accuracy: 0.9994 - loss: 0.0026
# Epoch 5/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 30s 2ms/step - accuracy: 0.9995 - loss: 0.0024
# Epoch 6/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 38s 3ms/step - accuracy: 0.9996 - loss: 0.0022
# Epoch 7/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 40s 3ms/step - accuracy: 0.9996 - loss: 0.0019
# Epoch 8/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 34s 2ms/step - accuracy: 0.9997 - loss: 0.0015
# Epoch 9/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 30s 2ms/step - accuracy: 0.9997 - loss: 0.0019
# Epoch 10/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 38s 3ms/step - accuracy: 0.9997 - loss: 0.0016
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2024/10/22 20:21:03 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# Logging metrics for model: MLP
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/22 20:21:06 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 20:21:06 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/10/22 20:21:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 20:21:18 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/10/22 20:21:26 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# <Sequential name=sequential, built=True>

# %%
model.model_lstm()
# Out:
# 2024/10/22 21:00:39 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 21:00:39 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 21:00:39 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 21:00:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model.model_lstm()
#
# File d:\10 A KAI 2/WEEK 8&9/Fraud_detection\script\model1.py:274, in FraudModel.model_lstm(self)
#     272 epochs = 10
#     273 batch_size = 32
# --> 274 model.fit(generator, epochs=epochs, verbose=1)
#     276 # Prediction
#     277 y_pred_prob = model.predict(test_generator, verbose=1)  # Get predicted probabilities
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\keras\src\models\functional.py:264, in Functional._adjust_input_rank(self, flat_inputs)
#     262             adjusted.append(ops.expand_dims(x, axis=-1))
#     263             continue
# --> 264     raise ValueError(
#     265         f"Invalid input shape for input {x}. Expected shape "
#     266         f"{ref_shape}, but input has incompatible shape {x.shape}"
#     267     )
#     268 # Add back metadata.
#     269 for i in range(len(flat_inputs)):
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Invalid input shape for input Tensor("Cast:0", shape=(None, 10, 10, 30), dtype=float32). Expected shape (None, 10, 10), but input has incompatible shape (None, 10, 10, 30)
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=(None, 10, 10, 30), dtype=float32)
#   • training=True
#   • mask=None

# %%
model.model_rnn()
# Out:
# 2024/10/22 20:56:45 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 20:56:45 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 20:56:45 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 20:56:49 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.model_rnn()
#
# File d:\10 A KAI 2/WEEK 8&9/Fraud_detection\script\model1.py:306, in FraudModel.model_rnn(self)
#     304 epochs = 10
#     305 batch_size = 32
# --> 306 model.fit(generator, epochs=epochs, verbose=1)
#     308 # Prediction
#     309 y_pred = (model.predict(test_generator) > 0.5).astype("int32")
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File d:\10 A KAI 2\WEEK 8&9\Fraud_detection\venv\Lib\site-packages\keras\src\models\functional.py:264, in Functional._adjust_input_rank(self, flat_inputs)
#     262             adjusted.append(ops.expand_dims(x, axis=-1))
#     263             continue
# --> 264     raise ValueError(
#     265         f"Invalid input shape for input {x}. Expected shape "
#     266         f"{ref_shape}, but input has incompatible shape {x.shape}"
#     267     )
#     268 # Add back metadata.
#     269 for i in range(len(flat_inputs)):
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Invalid input shape for input Tensor("Cast:0", shape=(None, 10, 10, 30), dtype=float32). Expected shape (None, 10, 10), but input has incompatible shape (None, 10, 10, 30)
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=(None, 10, 10, 30), dtype=float32)
#   • training=True
#   • mask=None

# %%
model.display_metrics_table()
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score       AUC
# 0  Logistic Regression  0.974264   0.058140  0.918367  0.109356  0.946364
# 1        Decision Tree  0.996963   0.334802  0.775510  0.467692  0.886427
# 2        Random Forest  0.999491   0.863158  0.836735  0.849741  0.918253
