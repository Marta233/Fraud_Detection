# %% [markdown]
# ### Task-2 Credit Card Fraud Model Devlopment

# %% [markdown]
# ####  --------Befoe each Model i did SMOTE because the class is highly immbalanced.
# ## Data Preprocessing
#
# ### Class Imbalance
# Initially, the dataset exhibited significant class imbalance, with the distribution of classes as follows:
#
# | Class       | Count    |
# |-------------|----------|
# | Fraud       | 492      |
# | Not Fraud   | 284,315 |
#
# This imbalance posed challenges for model training, as machine learning algorithms may tend to favor the majority class.
#
# ### Applying SMOTE
# To address this issue, we applied SMOTE, which generates synthetic examples of the minority class (fraud) to create a more balanced dataset. After applying SMOTE, the new class distribution was as follows:
#
# | Class       | Count    |
# |-------------|----------|
# | Fraud       | 499,500  |
# | Not Fraud   | 499,500  |
#
# With the application of SMOTE, the dataset now contains an equal number of samples for both classes, allowing for a more effective model training process.

# %%
import sys 
import pandas as pd
sys.path.insert(0, '/10 A KAI 2/WEEK 8&9/Fraud_detection/')

# %%
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
from script.model1 import  FraudModel

# %%
Data = pd.read_csv('../Data/credit_merged.csv', index_col=0)

# %%
Data.rename(columns={'Class': 'class'}, inplace=True)

# %%
model = FraudModel(Data, dataset_name="Credit", source="Credit Data Source")

# %%
import mlflow
mlflow.start_run()
# Out:
# <ActiveRun: >

# %%
Data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'class'],
#       dtype='object')

# %%
model.model_decision_tree()
# Out:
# 2024/10/29 16:44:06 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 16:44:06 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 16:44:06 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 16:45:24 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 16:45:40 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 16:45:40 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 16:45:41 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 16:46:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 16:46:46 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: The following failures occurred while performing one or more logging operations: [MlflowException('Failed to perform one or more operations on the run with ID 660be6bf6044466cae02fe6eef32cb7d. Failed operations: [MlflowException("Changing param values is not allowed. Param with key=\'n_neighbors\' was already logged with value=\'6\' for run ID=\'660be6bf6044466cae02fe6eef32cb7d\'. Attempted logging new value \'2\'.")]')]
# New class distribution in training set: [227451 113725]
# Logging metrics for model: Decision Tree
# Dataset name: Credit, Source: Credit Data Source
#
# Classification Report:
#  {'0': {'precision': 0.9996298450637195, 'recall': 0.9973269555430501, 'f1-score': 0.9984770724578994, 'support': 56864.0}, '1': {'precision': 0.33624454148471616, 'recall': 0.7857142857142857, 'f1-score': 0.4709480122324159, 'support': 98.0}, 'accuracy': 0.9969628875390611, 'macro avg': {'precision': 0.6679371932742179, 'recall': 0.8915206206286679, 'f1-score': 0.7347125423451577, 'support': 56962.0}, 'weighted avg': {'precision': 0.9984885269963986, 'recall': 0.9969628875390611, 'f1-score': 0.9975694876135803, 'support': 56962.0}}
# Attempting to save the model...
# Attempting to save model of type: <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Model Credit_Decision_Tree saved at models\Credit_Decision_Tree.pkl
# 2024/10/29 16:59:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model save attempted.
#
# Classification Report for Decision Tree:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.34      0.79      0.47        98
#
#     accuracy                           1.00     56962
#    macro avg       0.67      0.89      0.73     56962
# weighted avg       1.00      1.00      1.00     56962
# Pipeline(steps=[('decision_tree', DecisionTreeClassifier())])

# %%
model.model_random_forest()
# Out:
# 2024/10/29 16:59:12 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 16:59:12 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 16:59:12 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 16:59:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 16:59:17 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 16:59:17 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 16:59:17 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 16:59:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 16:59:21 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: The following failures occurred while performing one or more logging operations: [MlflowException('Failed to perform one or more operations on the run with ID 0395b4a844d049ee808ed6b3b9d589bb. Failed operations: [MlflowException("Changing param values is not allowed. Param with key=\'n_neighbors\' was already logged with value=\'6\' for run ID=\'0395b4a844d049ee808ed6b3b9d589bb\'. Attempted logging new value \'2\'.")]')]
# New class distribution in training set: [227451 113725]
# Logging metrics for model: Random Forest
# Dataset name: Credit, Source: Credit Data Source
#
# Classification Report:
#  {'0': {'precision': 0.9996834830927218, 'recall': 0.9997713843556556, 'f1-score': 0.9997274317920041, 'support': 56864.0}, '1': {'precision': 0.8602150537634409, 'recall': 0.8163265306122449, 'f1-score': 0.837696335078534, 'support': 98.0}, 'accuracy': 0.9994557775359011, 'macro avg': {'precision': 0.9299492684280813, 'recall': 0.9080489574839503, 'f1-score': 0.918711883435269, 'support': 56962.0}, 'weighted avg': {'precision': 0.9994435353016634, 'recall': 0.9994557775359011, 'f1-score': 0.9994486661679403, 'support': 56962.0}}
# Attempting to save random forest model...
# Attempting to save model of type: <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# Model Credit_Random_Forest saved at models\Credit_Random_Forest.pkl
# 2024/10/29 17:16:28 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Model save attempted.
#
# Classification Report for Random Forest:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.86      0.82      0.84        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.91      0.92     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model.model_mlp()
# Out:
# 2024/10/29 18:18:27 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 18:18:27 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 18:18:27 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 18:19:34 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 18:19:35 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 18:19:35 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 18:19:36 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 18:19:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 18:19:43 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: The following failures occurred while performing one or more logging operations: [MlflowException('Failed to perform one or more operations on the run with ID c7890c6db5f94e13a03b5470ec7c8e42. Failed operations: [MlflowException("Changing param values is not allowed. Param with key=\'n_neighbors\' was already logged with value=\'6\' for run ID=\'c7890c6db5f94e13a03b5470ec7c8e42\'. Attempted logging new value \'2\'.")]')]

# %%
model.model_lstm()
# Out:
# 2024/10/29 17:57:02 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 17:57:02 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 17:57:02 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 17:59:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 17:59:21 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 17:59:21 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 17:59:21 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 17:59:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 17:59:27 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: The following failures occurred while performing one or more logging operations: [MlflowException('Failed to perform one or more operations on the run with ID 079eb7112af340be9716c7ccf2b29544. Failed operations: [MlflowException("Changing param values is not allowed. Param with key=\'n_neighbors\' was already logged with value=\'6\' for run ID=\'079eb7112af340be9716c7ccf2b29544\'. Attempted logging new value \'2\'.")]')]
# New class distribution in training set: [227451 113725]
# 2024/10/29 18:10:38 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# An error occurred: FraudModel.model_lstm.<locals>.create_lstm_model() got an unexpected keyword argument 'epochs'
# Pipeline(steps=[('lstm_classifier',
#                  KerasClassifierWrapper(build_fn=<function FraudModel.model_lstm.<locals>.create_lstm_model at 0x000001BB8003EAC0>))])

# %%
model.display_metrics_table()
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score       AUC
# 0  Decision Tree  0.996963   0.998489  0.996963  0.997569  0.891521
# 1  Random Forest  0.999456   0.999444  0.999456  0.999449  0.908049
# 2            MLP  0.999350   0.999368  0.999350  0.999359  0.918183
