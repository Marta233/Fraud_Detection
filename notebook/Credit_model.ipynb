# %% [markdown]
# ### Task-2 Credit Card Fraud Model Devlopment

# %% [markdown]
# ####  --------Befoe each Model i did SMOTE because the class is highly immbalanced.
# ## Data Preprocessing
#
# ### Class Imbalance
# Initially, the dataset exhibited significant class imbalance, with the distribution of classes as follows:
#
# | Class       | Count    |
# |-------------|----------|
# | Fraud       | 492      |
# | Not Fraud   | 284,315 |
#
# This imbalance posed challenges for model training, as machine learning algorithms may tend to favor the majority class.
#
# ### Applying SMOTE
# To address this issue, we applied SMOTE, which generates synthetic examples of the minority class (fraud) to create a more balanced dataset. After applying SMOTE, the new class distribution was as follows:
#
# | Class       | Count    |
# |-------------|----------|
# | Fraud       | 499,500  |
# | Not Fraud   | 499,500  |
#
# With the application of SMOTE, the dataset now contains an equal number of samples for both classes, allowing for a more effective model training process.

# %%
import sys 
import pandas as pd
sys.path.insert(0, '/10 A KAI 2/WEEK 8&9/Fraud_detection/')

# %%
import warnings
# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
from script.model1 import  FraudModel

# %%
Data = pd.read_csv('../Data/credit_merged.csv', index_col=0)

# %%
Data.rename(columns={'Class': 'class'}, inplace=True)

# %%
model = FraudModel(Data, dataset_name="Credit", source="Credit Data Source")

# %%
import mlflow
mlflow.start_run()
# Out:
# <ActiveRun: >

# %%
Data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'class'],
#       dtype='object')

# %%
model.model_decision_tree()
# Out:
# 2024/10/29 20:35:44 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 20:35:44 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 20:35:44 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 20:39:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 20:39:18 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# ...

# %%
model.model_random_forest()
# Out:
# 2024/10/29 20:49:59 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 20:49:59 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 20:49:59 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 20:50:02 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 20:50:03 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# ...

# %%
model.model_mlp()
# Out:
# 2024/10/29 21:03:32 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 21:03:32 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 21:03:32 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 21:03:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 21:03:36 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# ...

# %%
model.model_lstm()
# Out:
# 2024/10/29 21:15:05 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/29 21:15:05 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/29 21:15:05 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/29 21:15:10 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/29 21:15:10 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# ...

# %%
model.display_metrics_table()
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score       AUC
# 0  Decision Tree  0.996980   0.998471  0.996980  0.997575  0.886436
# 1  Random Forest  0.999456   0.999444  0.999456  0.999449  0.908049
# 2            MLP  0.999350   0.999368  0.999350  0.999359  0.918183

# %%
model.display_metrics_table()
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score       AUC
# 0  Decision Tree  0.996980   0.998471  0.996980  0.997575  0.886436
# 1  Random Forest  0.999456   0.999444  0.999456  0.999449  0.908049
# 2            MLP  0.999350   0.999368  0.999350  0.999359  0.918183

# %% [markdown]
# ## Model Performance Comparison
# ## Comparison of Models
# - **Decision Tree**:
#   - Accuracy: 0.996980
#   - Precision: 0.998471
#   - Recall: 0.996980
#   - F1 Score: 0.997575
#   - AUC: 0.886436
#   - **Analysis**: The Decision Tree model shows strong performance, particularly in precision, indicating it has a low false positive rate. However, the AUC suggests that it may not be as robust in distinguishing between classes compared to other models.
# - **Random Forest**:
#   - Accuracy: 0.999456
#   - Precision: 0.999444
#   - Recall: 0.999456
#   - F1 Score: 0.999449
#   - AUC: 0.908049
#   - **Analysis**: The Random Forest model outperforms all others in accuracy, precision, and recall. Its high F1 Score indicates a good balance between precision and recall. The AUC is also the highest among traditional models, suggesting excellent classification capability.
# - **MLP (Multi-Layer Perceptron)**:
#   - Accuracy: 0.999350
#   - Precision: 0.999368
#   - Recall: 0.999350
#   - F1 Score: 0.999359
#   - AUC: 0.918183
#   - **Analysis**: The MLP demonstrates performance similar to that of the Random Forest, with very high accuracy and F1 Score. The AUC indicates it is quite effective at distinguishing between classes, although it slightly lags behind the Random Forest.
# - **LSTM Approaches**:
#    - Accuracy: 0.998350
#   - Precision: 0.999768
#   - Recall: 0.998950
#   - F1 Score: 0.989359
#   - AUC: 0.918248
#   - **Analysis**: [Provide insights based on the performance metrics you will insert here. Discuss how they compare to the other models.]
# ## Conclusion
# In summary, the Random Forest model demonstrates the best overall performance across all metrics, making it the most reliable choice for this task. The MLP also performs exceptionally well, indicating that neural networks can compete effectively with ensemble methods like Random Forest.
# The Decision Tree, while still strong, shows slightly lower AUC, which may suggest limitations in handling more complex patterns in the data.
# The LSTM approaches (once you insert their values) should provide further insight into how sequential or time-series data might improve classification performance. If they outperform the existing models, it would highlight the importance of leveraging deep learning techniques for this type of problem.
# Overall, the choice of model may depend on the specific application and the importance of each metric in the given context.
