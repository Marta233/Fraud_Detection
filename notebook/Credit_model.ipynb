# %% [markdown]
# ### Task-2 Credit Card Fraud Model Devlopment

# %% [markdown]
# ####  Befoe each Model i did SMOTE because the class is highly immbalanced.
# ## Data Preprocessing
#
# ### Class Imbalance
# Initially, the dataset exhibited significant class imbalance, with the distribution of classes as follows:
#
# | Class       | Count    |
# |-------------|----------|
# | Fraud       | 492      |
# | Not Fraud   | 284,315 |
#
# This imbalance posed challenges for model training, as machine learning algorithms may tend to favor the majority class.
#
# ### Applying SMOTE
# To address this issue, we applied SMOTE, which generates synthetic examples of the minority class (fraud) to create a more balanced dataset. After applying SMOTE, the new class distribution was as follows:
#
# | Class       | Count    |
# |-------------|----------|
# | Fraud       | 499,500  |
# | Not Fraud   | 499,500  |
#
# With the application of SMOTE, the dataset now contains an equal number of samples for both classes, allowing for a more effective model training process.

# %%
import sys 
import pandas as pd
sys.path.insert(0, '/10 A KAI 2/WEEK 8&9/Fraud_detection/')

# %%
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
from script.model1 import  FraudModel

# %%
Data = pd.read_csv('../Data/credit_merged.csv', index_col=0)

# %%
Data.rename(columns={'Class': 'class'}, inplace=True)

# %%
model = FraudModel(Data, dataset_name="Credit", source="Credit Data Source")

# %%
import mlflow
mlflow.start_run()
# Out:
# <ActiveRun: >

# %%
Data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'class'],
#       dtype='object')

# %%
model.model_logistic_regression()
# Out:
# 2024/10/22 23:38:42 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 23:38:42 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 23:38:42 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 23:38:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 23:39:44 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# Accuracy: 0.97
# Logging metrics for model: Logistic Regression
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/22 23:39:47 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# LogisticRegression()

# %%
model.model_rnn()
# Out:
# 2024/10/22 23:39:48 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 23:39:48 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 23:39:48 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 23:39:52 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 1/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - accuracy: 0.9871 - loss: 0.0380
# Epoch 2/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 35s 2ms/step - accuracy: 0.9989 - loss: 0.0046
# Epoch 3/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 35s 2ms/step - accuracy: 0.9992 - loss: 0.0033
# Epoch 4/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 42s 3ms/step - accuracy: 0.9994 - loss: 0.0025
# Epoch 5/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 38s 3ms/step - accuracy: 0.9995 - loss: 0.0022
# Epoch 6/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - accuracy: 0.9996 - loss: 0.0016
# Epoch 7/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 75s 2ms/step - accuracy: 0.9996 - loss: 0.0016
# Epoch 8/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 41s 3ms/step - accuracy: 0.9996 - loss: 0.0015
# Epoch 9/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 45s 3ms/step - accuracy: 0.9996 - loss: 0.0015
# Epoch 10/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 33s 2ms/step - accuracy: 0.9998 - loss: 0.0013
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Accuracy: 1.00
# Logging metrics for model: RNN
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/22 23:47:02 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 23:47:05 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 23:47:06 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/10/22 23:47:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/22 23:47:17 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/10/22 23:47:27 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# <Sequential name=sequential, built=True>

# %%
model.model_gradient_boosting()
# Out:
# 2024/10/22 23:47:27 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/22 23:47:27 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/22 23:47:27 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/22 23:47:32 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/23 00:05:51 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# Accuracy: 0.99
# Logging metrics for model: Gradient Boosting
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/23 00:05:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# GradientBoostingClassifier()

# %%
model.model_random_forest()
# Out:
# 2024/10/23 00:05:55 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/23 00:05:55 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/23 00:05:55 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/23 00:05:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Accuracy: 1.00
# 2024/10/23 00:53:25 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# RandomForestClassifier(random_state=42)

# %%
model.model_lstm()
# Out:
# 2024/10/23 00:53:25 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/23 00:53:25 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/23 00:53:25 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/23 00:53:30 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 1/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 39s 3ms/step - accuracy: 0.9858 - loss: 0.0402
# Epoch 2/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 35s 2ms/step - accuracy: 0.9992 - loss: 0.0036
# Epoch 3/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.9994 - loss: 0.0030
# Epoch 4/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.9996 - loss: 0.0019
# Epoch 5/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 35s 2ms/step - accuracy: 0.9996 - loss: 0.0018
# Epoch 6/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 42s 3ms/step - accuracy: 0.9997 - loss: 0.0014
# Epoch 7/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - accuracy: 0.9997 - loss: 0.0016
# Epoch 8/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.9998 - loss: 0.0011
# Epoch 9/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 36s 3ms/step - accuracy: 0.9998 - loss: 8.2965e-04
# Epoch 10/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 37s 3ms/step - accuracy: 0.9997 - loss: 0.0014
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# Accuracy: 1.00
# Logging metrics for model: LSTM
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/23 00:59:51 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/23 00:59:55 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/23 00:59:55 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/10/23 01:00:31 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/23 01:00:31 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/10/23 01:00:41 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# <Sequential name=sequential_1, built=True>

# %%
model.model_mlp()
# Out:
# 2024/10/23 01:00:42 WARNING mlflow.sklearn: Training metrics will not be recorded because training labels were not specified. To automatically record training metrics, provide training labels as inputs to the model training function.
# 2024/10/23 01:00:42 WARNING mlflow.sklearn: Failed to infer model signature: the trained model does not have a `predict` or `transform` function, which is required in order to infer the signature
# 2024/10/23 01:00:42 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# 2024/10/23 01:00:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Epoch 1/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 28s 2ms/step - accuracy: 0.9839 - loss: 0.0437
# Epoch 2/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 28s 2ms/step - accuracy: 0.9988 - loss: 0.0052
# Epoch 3/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 37s 2ms/step - accuracy: 0.9992 - loss: 0.0036
# Epoch 4/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.9993 - loss: 0.0030
# Epoch 5/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.9995 - loss: 0.0022
# Epoch 6/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.9996 - loss: 0.0021
# Epoch 7/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.9996 - loss: 0.0017
# Epoch 8/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 24s 2ms/step - accuracy: 0.9996 - loss: 0.0014
# Epoch 9/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 43s 2ms/step - accuracy: 0.9997 - loss: 0.0012
# Epoch 10/10
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 25s 2ms/step - accuracy: 0.9997 - loss: 0.0015
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
# 2024/10/23 01:05:35 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# Accuracy: 1.00
# Logging metrics for model: MLP
# Dataset name: Credit, Source: Credit Data Source
# 2024/10/23 04:05:45 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/10/23 04:05:45 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# 2024/10/24 18:31:07 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: C:\Users\marta\AppData\Local\Temp\tmps91johjv\model, flavor: keras). Fall back to return ['keras==3.6.0']. Set logging level to DEBUG to see the full traceback.
# 2024/10/24 18:31:08 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 14216/14216 ━━━━━━━━━━━━━━━━━━━━ 31s 2ms/step
# An error occurred: All fields in the model signature's input schema must be of type TensorSpec.
# <Sequential name=sequential_2, built=True>

# %%
model.display_metrics_table()
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score       AUC
# 0  Logistic Regression  0.974264   0.058140  0.918367  0.109356  0.946364
# 1                  RNN  0.998789   0.607407  0.836735  0.703863  0.917901
# 2    Gradient Boosting  0.986728   0.105516  0.897959  0.188841  0.942420
# 3                 LSTM  0.999157   0.723214  0.826531  0.771429  0.912993
# 4                  MLP  0.999087   0.694915  0.836735  0.759259  0.918051
